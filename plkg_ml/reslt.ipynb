# %% [markdown]
# # ML Result

# %% [markdown]
# * fnn
# * fnn_rssi
# * encoder
# * encoder_rssi

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from dataset import *

# %% [markdown]
# ### loss/epoch

# %%
plt.figure(figsize=(20,5))

losses = np.load('encoder/losses.npy')
plt.subplot(1,5,1)
plt.ylim(0.5,0.6)
plt.plot(losses[0],losses[1])
plt.title('encoder')
plt.ylabel('mse')
plt.xlabel('epoch')

losses = np.load('encoder_rssi/losses.npy')
plt.subplot(1,5,2)
plt.ylim(0.5,0.6)
plt.plot(losses[0],losses[1])
plt.title('encoder_rssi')
plt.ylabel('mse')
plt.xlabel('epoch')

losses = np.load('fnn/losses.npy')
plt.subplot(1,5,3)
plt.ylim(0.35,0.6)
plt.plot(losses[0],losses[1])
plt.title('fnn')
plt.ylabel('mse')
plt.xlabel('epoch')

losses = np.load('fnn_rssi/losses.npy')
plt.subplot(1,5,4)
plt.ylim(0.35,0.6)
plt.plot(losses[0],losses[1])
plt.title('fnn_rssi')
plt.ylabel('mse')
plt.xlabel('epoch')

losses = np.load('cnn_encoder_rssi/losses.npy')
plt.subplot(1,5,5)
plt.ylim(0.35,0.6)
plt.plot(losses[0],losses[1])
plt.title('cnn_encoder_rssi')
plt.ylabel('mse')
plt.xlabel('epoch')



plt.show()

# %% [markdown]
# ### testing

# %% [markdown]
# #### demo

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,4,1)
testset = np.load("normalized_testing_set.npy")
model = torch.load('encoder/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_dataset(testset)
data, iot_original = d_s.__getitem__(250)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('encoder')

plt.subplot(2,4,2)
testset = np.load("normalized_testing_set.npy")
model = torch.load('encoder_rssi/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_rssi_dataset(testset)
data, iot_original = d_s.__getitem__(250)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data[1:]
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('encoder_rssi')

plt.subplot(2,4,3)
testset = np.load("normalized_testing_set.npy")
model = torch.load('fnn/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_dataset(testset)
data, iot_original = d_s.__getitem__(250)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('fnn')

plt.subplot(2,4,4)
testset = np.load("normalized_testing_set.npy")
model = torch.load('fnn_rssi/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_rssi_dataset(testset)
data, iot_original = d_s.__getitem__(250)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data[1:]
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('fnn_rssi')


plt.subplot(2,4,5)
testset = np.load("normalized_testing_set.npy")
model = torch.load('encoder/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_dataset(testset)
data, iot_original = d_s.__getitem__(300)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('encoder')

plt.subplot(2,4,6)
testset = np.load("normalized_testing_set.npy")
model = torch.load('encoder_rssi/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_rssi_dataset(testset)
data, iot_original = d_s.__getitem__(300)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data[1:]
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('encoder_rssi')

plt.subplot(2,4,7)
testset = np.load("normalized_testing_set.npy")
model = torch.load('fnn/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_dataset(testset)
data, iot_original = d_s.__getitem__(300)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('fnn')

plt.subplot(2,4,8)
testset = np.load("normalized_testing_set.npy")
model = torch.load('fnn_rssi/model_final.pth')
model.to("cpu")
model.eval()
d_s = csi_rssi_dataset(testset)
data, iot_original = d_s.__getitem__(300)
index = torch.from_numpy(np.array([i+1 for i in range(51)]))
uav_original = data[1:]
uav_modify = model(data).detach().numpy()
plt.plot(index,iot_original,label = "iot_o")
plt.plot(index,uav_original,label = "uav_o")
plt.plot(index,uav_modify,label = "uav_m")
plt.legend(title = "name")
plt.title('fnn_rssi')

plt.show()

# %% [markdown]
# #### test mse

# %%
from training_core import *

# %%
testset = np.load("normalized_training_set.npy")


test_csi_loader = DataLoader(csi_dataset(testset),batch_size=1)
test_csi_rssi_loader = DataLoader(csi_rssi_dataset(testset),batch_size=1)

encoder_model = torch.load('encoder/model_final.pth')

encoder_loss = testing(encoder_model,test_csi_loader)

encoder_rssi_model = torch.load('encoder_rssi/model_final.pth')

encoder_rssi_loss = testing(encoder_rssi_model,test_csi_rssi_loader)

fnn_model = torch.load('fnn/model_final.pth')

fnn_loss = testing(fnn_model,test_csi_loader)

fnn_rssi_model = torch.load('fnn_rssi/model_final.pth')

fnn_rssi_loss = testing(fnn_rssi_model,test_csi_rssi_loader)

# %%
h = [encoder_loss,encoder_rssi_loss,fnn_loss,fnn_rssi_loss]
x = [i for i in range(4)]
label = ['encoder','encoder_rssi','fnn','fnn_rssi']
plt.bar(x,h,tick_label=label,width=0.5)
plt.ylabel('mse')
plt.ylim(12.5,17.5)
plt.title('training_total_mse')
plt.show()

# %%
testset = np.load("normalized_testing_set.npy")


test_csi_loader = DataLoader(csi_dataset(testset),batch_size=1)
test_csi_rssi_loader = DataLoader(csi_rssi_dataset(testset),batch_size=1)

encoder_model = torch.load('encoder/model_final.pth')

encoder_loss = testing(encoder_model,test_csi_loader)

encoder_rssi_model = torch.load('encoder_rssi/model_final.pth')

encoder_rssi_loss = testing(encoder_rssi_model,test_csi_rssi_loader)

fnn_model = torch.load('fnn/model_final.pth')

fnn_loss = testing(fnn_model,test_csi_loader)

fnn_rssi_model = torch.load('fnn_rssi/model_final.pth')

fnn_rssi_loss = testing(fnn_rssi_model,test_csi_rssi_loader)

# %%
h = [encoder_loss,encoder_rssi_loss,fnn_loss,fnn_rssi_loss]
x = [i for i in range(4)]
label = ['encoder','encoder_rssi','fnn','fnn_rssi']
plt.bar(x,h,tick_label=label,width=0.5)
plt.ylabel('mse')
plt.ylim(3,5)
plt.title('testing_total_mse')
plt.show()
